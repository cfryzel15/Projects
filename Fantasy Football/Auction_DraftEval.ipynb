# %%
## import packages 

from bs4 import BeautifulSoup as Soup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import pulp
import re

# %%
## Input point values URL (very specific to Draft Sharks - the thing with BS is it's kind of unique to each page)

ffc_response = requests.get('https://www.draftsharks.com/adp/half/all?AdpForm%5BleagueSize%5D=12')

# %%
## parse data with Soup (creates nested Tags) 

adp_soup = Soup(ffc_response.text) 
tables = adp_soup.find_all('table')

## since the table is in a list with 'tables', you have to access the actual element in the list

adp_table = tables[0]

# %%
## the table is still nested, so run find_all to return the 'tr' (table rows) 

rows = adp_table.find_all('tr')

# %%
## now parse the entire table down to list form

temp = [x.find_all('td') for x in rows]

# %%
## iterate through rows of list #temp and then iterate through THOSE values with get_text

clean = [([str(y.get_text()) for y in x]) for x in temp]

# %%
## convert final list of lists to a data frame 

df = pd.DataFrame(clean)
df.head()
# Out:
#                            0                   1     2     3       4
# 0                       None                None  None  None    None
# 1      1. Justin JeffersonWR  1.1   Show Trend »    13   207  284.20
# 2   2. Christian McCaffreyRB  1.2   Show Trend »     9   226  238.35
# 3         3. Ja'Marr ChaseWR  1.3   Show Trend »     7   200  266.85
# 4           4. Tyreek HillWR  1.4   Show Trend »    10   187  262.15

# %%
## Drop first row 
df.drop(0, axis = 0, inplace = True)

## split first column for name/position 

df['position'] = df[0].str[-2:]

## Name your columns

df.columns = ['name', 'avg_position', 'bye_week', 'consensus_points', 'ds_points', 'position']

df['name'] = df['name'].str[:-2]

## remove the numeric values from player names and then remove the '.' from the beginning 

df['name'] = df['name'].str.replace('\d+', '')
df['name'] = df['name'].str[2:]

## drop ADP column since we don't need it for an auction draft
df.drop('avg_position', axis = 1, inplace = True)
df.drop('bye_week', axis = 1, inplace = True)
## Everything is in string form, so we need to make them the right data type

float_cols =['ds_points']
int_cols =['consensus_points'] 

df[float_cols] = df[float_cols].astype(float)
df[int_cols] = df[int_cols].astype(int)

# %%
## create positional tables for use 
df_wr = df.loc[df['position'] == 'WR']
df_rb = df.loc[df['position'] == 'RB']
df_qb = df.loc[df['position'] == 'QB']
df_te = df.loc[df['position'] == 'TE']

# %%
## sort values and reset index
df_wr.sort_values(['consensus_points'], ascending = False, inplace = True)
df_wr.reset_index(inplace = True, drop = True)
df_rb.sort_values(['consensus_points'], ascending = False, inplace = True)
df_rb.reset_index(inplace = True, drop = True)
df_qb.sort_values(['consensus_points'], ascending = False, inplace = True)
df_qb.reset_index(inplace = True, drop = True)
df_te.sort_values(['consensus_points'], ascending = False, inplace = True)
df_te.reset_index(inplace = True, drop = True)
# Out:
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## Set budgets 
wr_rb_budget = 69
qb_te_budget = 28

# %%
## Set # of Starters for the league
wr_rb_starters = 30 ## 2.5 starters per position (2 starters WR/RB(4) + 1 flex)
qb_te_starters = 12

# %%
## Set # of bench players for the league
wr_rb_bench = 24 ## 2 per team/position. 
qb_te_bench = 6 ## not enough quality starters for everyone to carry 1 backup (planning for adds/drops on byes)

# %%
## calculate replacement player value (avg of the bench players (aka $1 players/replaceable) 
## UPDATE: 2023 Post Draft Analysis - Everyone goes hard early. Avg of 4.5 players/team with over $10 bids. 
    ## Adjusting replacement player value to 90th percentile of bench players instead of 20th. Won't make a huge
    ## difference but worth adjusting 
wr_replacement_value = df_wr['consensus_points'].iloc[wr_rb_starters:(wr_rb_starters + wr_rb_bench)].quantile(.9)
rb_replacement_value = df_rb['consensus_points'].iloc[wr_rb_starters:(wr_rb_starters + wr_rb_bench)].quantile(.9)
qb_replacement_value = df_qb['consensus_points'].iloc[qb_te_starters:(qb_te_starters + qb_te_bench)].quantile(.9)
te_replacement_value = df_te['consensus_points'].iloc[qb_te_starters:(qb_te_starters + qb_te_bench)].quantile(.9)

# %%
## calculate cost per point value (budget / ((max points - replacement points) * .95) 
## use 95th percentile to help adjust for outliers. Or what about a weighted percentile? 

wr_cpp = wr_rb_budget / (df_wr['consensus_points'].max() - wr_replacement_value)
rb_cpp = wr_rb_budget / (df_rb['consensus_points'].max() - rb_replacement_value)
qb_cpp = qb_te_budget / (df_qb['consensus_points'].max() - qb_replacement_value)
te_cpp = qb_te_budget / (df_te['consensus_points'].iloc[1] - te_replacement_value)  ## **Manually adjusting for Kelce

# %%
## calculate auction value (projection - replacement value) * cost per point

df_wr['auction_value'] = (df_wr['consensus_points'] - wr_replacement_value) * wr_cpp
df_rb['auction_value'] = (df_rb['consensus_points'] - rb_replacement_value) * rb_cpp
df_qb['auction_value'] = (df_qb['consensus_points'] - qb_replacement_value) * qb_cpp
df_te['auction_value'] = (df_te['consensus_points'] - te_replacement_value) * te_cpp
# Out:
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_wr.iloc[0:36]
# Out:
#                   name  consensus_points  ds_points position  auction_value
# 0     Justin Jefferson               207     284.20       WR      69.000000
# 1        Ja'Marr Chase               200     266.85       WR      63.194712
# 2          Tyreek Hill               187     262.15       WR      52.413462
# 3          Cooper Kupp               186     259.95       WR      51.584135
# 4           A.J. Brown               186     223.75       WR      51.584135
# 5         Stefon Diggs               179     246.25       WR      45.778846
# 6        Davante Adams               177     229.15       WR      44.120192
# 7          CeeDee Lamb               174     236.30       WR      41.632212
# 8        Jaylen Waddle               158     202.60       WR      28.362981
# 9    Amon-Ra St. Brown               153     231.25       WR      24.216346
# 10      Garrett Wilson               150     212.00       WR      21.728365
# 11         Tee Higgins               150     201.55       WR      21.728365
# 12        Amari Cooper               150     185.65       WR      21.728365
# 13        Deebo Samuel               149     187.10       WR      20.899038
# 14       DeVonta Smith               148     189.85       WR      20.069712
# 15         Chris Olave               145     203.80       WR      17.581731
# 16       Mike Williams               142     185.30       WR      15.093750
# 17          Mike Evans               141     162.95       WR      14.264423
# 18        D.K. Metcalf               140     197.40       WR      13.435096
# 19         Jerry Jeudy               140     179.65       WR      13.435096
# 20     DeAndre Hopkins               139     162.60       WR      12.605769
# 21    Christian Watson               138     179.80       WR      11.776442
# 22      Terry McLaurin               137     173.80       WR      10.947115
# 23        Keenan Allen               136     187.65       WR      10.117788
# 24       Calvin Ridley               135     192.95       WR       9.288462
# 25          D.J. Moore               134     169.50       WR       8.459135
# 26       Tyler Lockett               131     185.75       WR       5.971154
# 27       Brandon Aiyuk               129     161.10       WR       4.312500
# 28        Chris Godwin               129     171.00       WR       4.312500
# 29      Marquise Brown               129     158.30       WR       4.312500
# 30        Drake London               127     174.95       WR       2.653846
# 31        Jahan Dotson               125     152.90       WR       0.995192
# 32      Christian Kirk               125     170.90       WR       0.995192
# 33       Gabriel Davis               121     158.95       WR      -2.322115
# 34     Diontae Johnson               116     155.00       WR      -6.468750
# 35       Brandin Cooks               115     139.00       WR      -7.298077

# %%
## repeat for ds point values 
## sort values and reset index
df_wr.sort_values(['ds_points'], ascending = False, inplace = True)
df_wr.reset_index(inplace = True, drop = True)
df_rb.sort_values(['ds_points'], ascending = False, inplace = True)
df_rb.reset_index(inplace = True, drop = True)
df_qb.sort_values(['ds_points'], ascending = False, inplace = True)
df_qb.reset_index(inplace = True, drop = True)
df_te.sort_values(['ds_points'], ascending = False, inplace = True)
df_te.reset_index(inplace = True, drop = True)

## calculate replacement player value (avg of the bench players (aka $1 players/replaceable) 
## UPDATE: 2023 Post Draft Analysis - Everyone goes hard early. Avg of 4.5 players/team with over $10 bids. 
    ## Adjusting replacement player value to 80th percentile of bench players instead of 20th. Won't make a huge
    ## difference but worth adjusting 
wr_replacement_value_ds = df_wr['ds_points'].iloc[wr_rb_starters:(wr_rb_starters + wr_rb_bench)].quantile(.9)
rb_replacement_value_ds = df_rb['ds_points'].iloc[wr_rb_starters:(wr_rb_starters + wr_rb_bench)].quantile(.9)
qb_replacement_value_ds = df_qb['ds_points'].iloc[qb_te_starters:(qb_te_starters + qb_te_bench)].quantile(.9)
te_replacement_value_ds = df_te['ds_points'].iloc[qb_te_starters:(qb_te_starters + qb_te_bench)].quantile(.9)

## calculate cost per point value (budget / ((max points - replacement points) * .95) 
## use 95th percentile to help adjust for outliers. Or what about a weighted percentile? 

wr_cpp_ds = wr_rb_budget / (df_wr['ds_points'].max() - wr_replacement_value_ds)
rb_cpp_ds = wr_rb_budget / (df_rb['ds_points'].max() - rb_replacement_value_ds)
qb_cpp_ds = qb_te_budget / (df_qb['ds_points'].iloc[1] - qb_replacement_value_ds) ## ** Manually adjusting for Allen
te_cpp_ds = qb_te_budget / (df_te['ds_points'].iloc[1] - te_replacement_value_ds) ##** manually  adjusting for Kelce

## based on elboberto method - surplus value at an aggregate level

df_wr['surplus_ds'] = df_wr['ds_points'] - wr_replacement_value_ds
df_rb['surplus_ds'] = df_rb['ds_points'] - rb_replacement_value_ds
df_qb['surplus_ds'] = df_qb['ds_points'] - qb_replacement_value_ds
df_te['surplus_ds'] = df_te['ds_points'] - te_replacement_value_ds

## calculate auction value (projection - replacement value) * cost per point

df_wr['auction_value_ds'] = (df_wr['ds_points'] - wr_replacement_value_ds) * wr_cpp_ds
df_rb['auction_value_ds'] = (df_rb['ds_points'] - rb_replacement_value_ds) * rb_cpp_ds
df_qb['auction_value_ds'] = (df_qb['ds_points'] - qb_replacement_value_ds) * qb_cpp_ds
df_te['auction_value_ds'] = (df_te['ds_points'] - te_replacement_value_ds) * te_cpp_ds
# Out:
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/cameronfryzel/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
## union data frames back together

df_final = pd.concat([df_wr, df_rb, df_qb, df_te])

# %%
df_final.reset_index(inplace = True)

# %%
df_final['auction_value'] = np.where(df_final['auction_value'] <= 1 ,
                       1,
                       df_final['auction_value'])

# %%
df_final['auction_value_ds'] = np.where(df_final['auction_value_ds'] <= 1 ,
                       1,
                       df_final['auction_value_ds'])

# %%
df_final.loc[df_final['position'] == 'QB']

##df_final
# Out:
#      index                       name  consensus_points  ds_points position  \
# 281      0                 Josh Allen               379      415.7       QB
# 282      1            Patrick Mahomes               378      374.4       QB
# 283      2                Jalen Hurts               385      360.8       QB
# 284      3              Lamar Jackson               363      356.5       QB
# 285      4             Justin Herbert               326      342.5       QB
# ..     ...                        ...               ...        ...      ...
# 337     56   Dorian Thompson-Robinson                 8        0.0       QB
# 338     57                Jake Haener                 6        0.0       QB
# 339     58               Tanner McKee                 4        0.0       QB
# 340     59           Malik Cunningham                 1        0.0       QB
# 341     60              Chase Garbers                 0        0.0       QB
#
#      auction_value  surplus_ds  auction_value_ds
# 281      26.112360      126.55         41.564809
# 282      25.797753       85.25         28.000000
# 283      28.000000       71.65         23.533138
# 284      21.078652       67.35         22.120821
# 285       9.438202       53.35         17.522581
# ..             ...         ...               ...
# 337       1.000000     -289.15          1.000000
# 338       1.000000     -289.15          1.000000
# 339       1.000000     -289.15          1.000000
# 340       1.000000     -289.15          1.000000
# 341       1.000000     -289.15          1.000000
#
# [61 rows x 8 columns]

# %%
df_final['surplus_ds'] = np.where(df_final['surplus_ds'] <= 0 ,
                       0,
                       df_final['surplus_ds'])

# %%
## surplus

cpp_v2 = (199 * 12) / df_final['surplus_ds'].sum()

# %%
df_final['surplus_auction_value'] = df_final['surplus_ds'] * cpp_v2

# %%
df_final.loc[df_final['position'] == 'QB'].head(50)
# Out:
#      index                 name  consensus_points  ds_points position  \
# 281      0           Josh Allen               379      415.7       QB
# 282      1      Patrick Mahomes               378      374.4       QB
# 283      2          Jalen Hurts               385      360.8       QB
# 284      3        Lamar Jackson               363      356.5       QB
# 285      4       Justin Herbert               326      342.5       QB
# 286      5           Joe Burrow               342      341.5       QB
# 287      6      Trevor Lawrence               314      318.9       QB
# 288      7       Deshaun Watson               313      318.0       QB
# 289      8        Justin Fields               338      311.2       QB
# 290      9         Kirk Cousins               294      307.1       QB
# 291     10   Anthony Richardson               292      298.3       QB
# 292     11           Geno Smith               299      297.1       QB
# 293     12       Tua Tagovailoa               298      289.4       QB
# 294     13         Dak Prescott               306      288.9       QB
# 295     14         Daniel Jones               305      287.0       QB
# 296     15           Jared Goff               273      275.4       QB
# 297     16       Russell Wilson               289      267.2       QB
# 298     17        Aaron Rodgers               291      263.8       QB
# 299     18        Kenny Pickett               257      262.5       QB
# 300     19           Derek Carr               241      251.4       QB
# 301     20          Jordan Love               254      251.1       QB
# 302     21          Bryce Young               261      248.3       QB
# 303     22            Mac Jones               235      247.0       QB
# 304     23     Matthew Stafford               261      246.9       QB
# 305     24          C.J. Stroud               233      236.5       QB
# 306     25           Sam Howell               262      232.1       QB
# 307     26       Ryan Tannehill               250      232.0       QB
# 308     27         Kyler Murray               262      218.4       QB
# 309     28      Jimmy Garoppolo               245      213.5       QB
# 310     29          Brock Purdy               268      205.5       QB
# 311     30       Baker Mayfield               211      198.9       QB
# 312     31       Desmond Ridder               226      197.4       QB
# 313     32           Kyle Trask                73       53.5       QB
# 314     33      Jacoby Brissett                38       48.8       QB
# 315     34           Trey Lance                32       39.1       QB
# 316     35           Colt McCoy                54       38.1       QB
# 317     36      Taylor Heinicke                29       37.4       QB
# 318     37       Marcus Mariota                26       34.5       QB
# 319     38           Mike White                27       34.4       QB
# 320     39        Tyler Huntley                23       33.2       QB
# 321     40          Sam Darnold                26       30.8       QB
# 322     41      Jarrett Stidham                23       30.8       QB
# 323     42           Will Levis                27       29.1       QB
# 324     43         Tyrod Taylor                20       29.0       QB
# 325     44          Zach Wilson                21       28.7       QB
# 326     45      Stetson Bennett                17       26.9       QB
# 327     46      Gardner Minshew                19       16.4       QB
# 328     47         Bailey Zappe                23       14.3       QB
# 329     48         Carson Wentz                13       14.2       QB
# 330     49          Davis Mills                16       12.4       QB
#
#      auction_value  surplus_ds  auction_value_ds  surplus_auction_value
# 281      26.112360      126.55         41.564809              72.861400
# 282      25.797753       85.25         28.000000              49.082848
# 283      28.000000       71.65         23.533138              41.252622
# 284      21.078652       67.35         22.120821              38.776889
# 285       9.438202       53.35         17.522581              30.716363
# 286      14.471910       52.35         17.194135              30.140611
# 287       5.662921       29.75          9.771261              17.128618
# 288       5.348315       28.85          9.475660              16.610442
# 289      13.213483       22.05          7.242229              12.695329
# 290       1.000000       17.95          5.895601              10.334746
# 291       1.000000        9.15          3.005279               5.268130
# 292       1.000000        7.95          2.611144               4.577227
# 293       1.000000        0.25          1.000000               0.143938
# 294       3.146067        0.00          1.000000               0.000000
# 295       2.831461        0.00          1.000000               0.000000
# 296       1.000000        0.00          1.000000               0.000000
# 297       1.000000        0.00          1.000000               0.000000
# 298       1.000000        0.00          1.000000               0.000000
# 299       1.000000        0.00          1.000000               0.000000
# 300       1.000000        0.00          1.000000               0.000000
# 301       1.000000        0.00          1.000000               0.000000
# 302       1.000000        0.00          1.000000               0.000000
# 303       1.000000        0.00          1.000000               0.000000
# 304       1.000000        0.00          1.000000               0.000000
# 305       1.000000        0.00          1.000000               0.000000
# 306       1.000000        0.00          1.000000               0.000000
# 307       1.000000        0.00          1.000000               0.000000
# 308       1.000000        0.00          1.000000               0.000000
# 309       1.000000        0.00          1.000000               0.000000
# 310       1.000000        0.00          1.000000               0.000000
# 311       1.000000        0.00          1.000000               0.000000
# 312       1.000000        0.00          1.000000               0.000000
# 313       1.000000        0.00          1.000000               0.000000
# 314       1.000000        0.00          1.000000               0.000000
# 315       1.000000        0.00          1.000000               0.000000
# 316       1.000000        0.00          1.000000               0.000000
# 317       1.000000        0.00          1.000000               0.000000
# 318       1.000000        0.00          1.000000               0.000000
# 319       1.000000        0.00          1.000000               0.000000
# 320       1.000000        0.00          1.000000               0.000000
# 321       1.000000        0.00          1.000000               0.000000
# 322       1.000000        0.00          1.000000               0.000000
# 323       1.000000        0.00          1.000000               0.000000
# 324       1.000000        0.00          1.000000               0.000000
# 325       1.000000        0.00          1.000000               0.000000
# 326       1.000000        0.00          1.000000               0.000000
# 327       1.000000        0.00          1.000000               0.000000
# 328       1.000000        0.00          1.000000               0.000000
# 329       1.000000        0.00          1.000000               0.000000
# 330       1.000000        0.00          1.000000               0.000000

# %%
## Set up for objective function 
## convert to dictionaries (data sharks first) 

##create empty dictionaries
values = {}
points = {}
##iterate through unique positions
for pos in df_final.position.unique():
    ## create temp df of each position
    available_pos = df_final[df_final.position == pos]
    ## create k/v pairs for player and auction value
    value = list(available_pos[["name","auction_value_ds"]].set_index("name").to_dict().values())[0]
    point = list(available_pos[["name","ds_points"]].set_index("name").to_dict().values())[0]
    ## insert into dicts
    values[pos] = value
    points[pos] = point

# %%
points
# Out:
# {'WR': {' Justin Jefferson': 284.2,
#   " Ja'Marr Chase": 266.85,
#   ' Tyreek Hill': 262.15,
#   ' Cooper Kupp': 259.95,
#   ' Stefon Diggs': 246.25,
#   ' CeeDee Lamb': 236.3,
#   ' Amon-Ra St. Brown': 231.25,
#   ' Davante Adams': 229.15,
#   ' A.J. Brown': 223.75,
#   ' Garrett Wilson': 212.0,
#   ' Chris Olave': 203.8,
#   ' Jaylen Waddle': 202.6,
#   ' Tee Higgins': 201.55,
#   ' D.K. Metcalf': 197.4,
#   ' Calvin Ridley': 192.95,
#   ' DeVonta Smith': 189.85,
#   ' Keenan Allen': 187.65,
#   ' Deebo Samuel': 187.1,
#   ' Tyler Lockett': 185.75,
#   ' Amari Cooper': 185.65,
#   ' Mike Williams': 185.3,
#   ' Christian Watson': 179.8,
#   ' Jerry Jeudy': 179.65,
#   ' Drake London': 174.95,
#   ' Terry McLaurin': 173.8,
#   ' Chris Godwin': 171.0,
#   ' Christian Kirk': 170.9,
#   ' D.J. Moore': 169.5,
#   ' Mike Evans': 162.95,
#   ' DeAndre Hopkins': 162.6,
#   ' Jordan Addison': 162.5,
#   ' Brandon Aiyuk': 161.1,
#   ' Gabriel Davis': 158.95,
#   ' Marquise Brown': 158.3,
#   ' Michael Pittman': 158.3,
#   ' Diontae Johnson': 155.0,
#   ' Jahan Dotson': 152.9,
#   ' Jaxon Smith-Njigba': 151.6,
#   ' Treylon Burks': 151.55,
#   ' George Pickens': 148.9,
#   ' Zay Flowers': 147.2,
#   ' Quentin Johnston': 146.3,
#   ' Elijah Moore': 145.4,
#   ' Zay Jones': 140.85,
#   ' Courtland Sutton': 140.55,
#   ' Allen Lazard': 139.9,
#   ' Brandin Cooks': 139.0,
#   ' Tyler Boyd': 138.45,
#   ' Skyy Moore': 134.95,
#   ' Nico Collins': 133.95,
#   ' JuJu Smith-Schuster': 133.35,
#   ' Rondale Moore': 130.15,
#   ' Michael Gallup': 128.3,
#   ' Kadarius Toney': 127.4,
#   ' Jakobi Meyers': 127.25,
#   ' Rashod Bateman': 127.1,
#   ' Darius Slayton': 125.1,
#   ' Isaiah Hodgins': 124.95,
#   ' Adam Thielen': 122.85,
#   ' Curtis Samuel': 122.25,
#   ' Romeo Doubs': 122.0,
#   ' Van Jefferson': 120.5,
#   ' Michael Thomas': 119.05,
#   ' Donovan Peoples-Jones': 116.65,
#   ' Odell Beckham Jr.': 115.5,
#   ' Robert Woods': 112.05,
#   ' Jonathan Mingo': 111.6,
#   ' K.J. Osborn': 105.95,
#   ' Rashid Shaheed': 103.4,
#   ' D.J. Chark': 101.55,
#   ' Darnell Mooney': 100.4,
#   ' Marquez Valdes-Scantling': 100.3,
#   ' Jayden Reed': 99.35,
#   ' Mecole Hardman': 96.75,
#   ' Rashee Rice': 94.95,
#   ' DeVante Parker': 94.65,
#   ' Corey Davis': 93.95,
#   ' Parris Campbell': 93.5,
#   ' Alec Pierce': 93.5,
#   ' Josh Downs': 91.35,
#   ' Nathaniel Dell': 90.95,
#   ' Chase Claypool': 89.35,
#   ' Jameson Williams': 88.55,
#   ' Kendrick Bourne': 85.5,
#   ' Tutu Atwell': 83.75,
#   ' Mack Hollins': 83.15,
#   ' Michael Wilson': 83.05,
#   ' Tyquan Thornton': 82.35,
#   ' Hunter Renfrow': 81.05,
#   ' Terrace Marshall': 80.3,
#   ' Jalin Hyatt': 79.55,
#   ' Deonte Harty': 79.05,
#   ' Josh Reynolds': 77.85,
#   ' Richie James': 76.1,
#   ' Allen Robinson': 74.55,
#   ' Josh Palmer': 72.95,
#   ' Marvin Jones': 70.4,
#   ' John Metchie': 67.7,
#   ' Puka Nacua': 63.55,
#   ' Cedric Tillman': 62.7,
#   ' Braxton Berrios': 61.85,
#   ' Justin Watson': 61.25,
#   ' Greg Dortch': 60.65,
#   ' Khalil Shakir': 60.05,
#   ' Jauan Jennings': 59.9,
#   ' Justyn Ross': 57.9,
#   " Wan'Dale Robinson": 55.9,
#   ' Demario Douglas': 55.0,
#   ' Quez Watkins': 53.35,
#   ' Jarvis Landry': 52.9,
#   ' Laviska Shenault': 52.8,
#   ' Kalif Raymond': 50.65,
#   ' Trent Sherfield': 49.75,
#   ' Marquez Callaway': 48.2,
#   ' Jalen Nailor': 47.1,
#   ' Isaiah McKenzie': 46.95,
#   ' Cedrick Wilson': 45.55,
#   ' Olamide Zaccheaus': 45.45,
#   ' Charlie Jones': 43.45,
#   ' Jamal Agnew': 43.25,
#   ' Chosen Anderson': 42.75,
#   ' Devin Duvernay': 42.3,
#   ' Nick Westbrook-Ikhine': 42.25,
#   ' Kyle Philips': 39.65,
#   ' Kenny Golladay': 39.4,
#   ' Jalen Tolbert': 39.3,
#   ' David Bell': 38.75,
#   ' DeAndre Carter': 38.45,
#   ' Trenton Irwin': 38.2,
#   " Tre'Quan Smith": 37.15,
#   ' Ben Skowronek': 36.4,
#   ' Sterling Shepard': 35.55,
#   ' Samori Toure': 35.25,
#   ' Noah Brown': 34.65,
#   ' Randall Cobb': 34.5,
#   ' Jalen Guyton': 34.35,
#   ' Nelson Agholor': 33.65,
#   ' Parker Washington': 33.6,
#   ' Marquise Goodwin': 31.25,
#   ' Denzel Mims': 31.15,
#   ' Danny Gray': 30.15,
#   ' A.T. Perry': 29.7,
#   ' K.J. Hamler': 29.5,
#   ' Xavier Hutchinson': 29.35,
#   ' Scott Miller': 28.95,
#   ' Cole Beasley': 28.05,
#   ' Kayshon Boutte': 27.95,
#   ' Tyler Scott': 26.5,
#   ' Demetric Felton': 24.6,
#   ' Ray-Ray McCloud': 22.8,
#   ' Laquon Treadwell': 22.6,
#   ' Kendall Hinton': 18.15,
#   ' Equanimeous St. Brown': 18.0,
#   ' Russell Gage': 0.0,
#   ' Antoine Wesley': 0.0,
#   ' Henry Ruggs': 0.0,
#   ' KaVontae Turpin': 0.0,
#   ' Racey McMath': 0.0,
#   ' Tom Kennedy': 0.0,
#   ' Malik Flowers': 0.0,
#   ' Colton Dowell': 0.0},
#  'RB': {' Austin Ekeler': 244.75,
#   ' Derrick Henry': 243.75,
#   ' Saquon Barkley': 243.45,
#   ' Nick Chubb': 242.85,
#   ' Bijan Robinson': 240.85,
#   ' Christian McCaffrey': 238.35,
#   ' Tony Pollard': 236.0,
#   ' Jonathan Taylor': 233.65,
#   ' Josh Jacobs': 228.4,
#   ' Joe Mixon': 215.05,
#   ' Rhamondre Stevenson': 205.8,
#   ' Najee Harris': 204.45,
#   ' J.K. Dobbins': 204.2,
#   ' Cam Akers': 201.2,
#   ' Travis Etienne': 197.45,
#   ' Kenneth Walker': 196.05,
#   ' Alexander Mattison': 195.05,
#   ' Jahmyr Gibbs': 192.35,
#   ' Dameon Pierce': 189.05,
#   ' Aaron Jones': 187.5,
#   ' David Montgomery': 186.85,
#   ' Rachaad White': 186.45,
#   ' Breece Hall': 183.6,
#   ' Miles Sanders': 182.7,
#   ' Javonte Williams': 179.25,
#   ' James Conner': 173.45,
#   ' Isiah Pacheco': 167.75,
#   ' James Cook': 163.75,
#   ' Brian Robinson': 157.35,
#   ' Alvin Kamara': 155.6,
#   ' A.J. Dillon': 152.9,
#   ' Khalil Herbert': 151.15,
#   " D'Andre Swift": 147.25,
#   ' Dalvin Cook': 139.6,
#   ' Antonio Gibson': 134.3,
#   ' Samaje Perine': 127.7,
#   ' Damien Harris': 118.35,
#   ' Jerick McKinnon': 116.55,
#   ' Jeff Wilson Jr.': 115.8,
#   ' Zach Charbonnet': 114.05,
#   ' Rashaad Penny': 111.95,
#   ' Jamaal Williams': 110.4,
#   ' Raheem Mostert': 108.9,
#   ' Jaylen Warren': 105.75,
#   ' Devin Singletary': 97.05,
#   ' Devon Achane': 96.0,
#   ' Tank Bigsby': 95.75,
#   ' Kenneth Gainwell': 91.55,
#   ' Tyler Allgeier': 88.35,
#   ' Leonard Fournette': 80.55,
#   ' Ezekiel  Elliott': 75.45,
#   ' Roschon Johnson': 74.9,
#   ' Chuba Hubbard': 74.75,
#   ' Kendre Miller': 73.1,
#   ' Elijah Mitchell': 73.1,
#   " D'Onta  Foreman": 72.95,
#   ' Kareem Hunt': 67.8,
#   ' Tyjae Spears': 66.35,
#   ' Zamir White': 65.5,
#   ' Jerome Ford': 64.75,
#   ' Ty Chandler': 63.65,
#   ' Joshua Kelley': 60.9,
#   ' Kyren Williams': 60.7,
#   " Ke'Shawn Vaughn": 59.5,
#   ' Cordarrelle Patterson': 59.05,
#   ' Gus Edwards': 58.85,
#   ' Clyde Edwards-Helaire': 57.4,
#   ' Keaontay Ingram': 55.95,
#   ' Evan Hull': 55.0,
#   ' Chase Brown': 54.1,
#   ' Jordan Mason': 53.35,
#   ' Chris Evans': 51.45,
#   ' Matt Breida': 50.75,
#   ' Zack Moss': 47.15,
#   ' Deuce Vaughn': 45.75,
#   ' Isaiah Spiller': 45.7,
#   ' Michael Carter': 44.8,
#   ' Kenyan Drake': 43.1,
#   ' DeWayne McBride': 40.0,
#   ' Zach Evans': 39.2,
#   ' Pierre Strong Jr.': 37.85,
#   ' Trayveon Williams': 36.25,
#   ' Latavius Murray': 35.5,
#   ' JaMycal Hasty': 34.9,
#   ' Chase Edmonds': 34.5,
#   ' Israel Abanikanda': 34.05,
#   ' Melvin Gordon': 33.8,
#   ' Eric Gray': 32.85,
#   ' Rico Dowdle': 32.75,
#   ' Kenny McIntosh': 31.9,
#   ' DeeJay Dallas': 31.7,
#   ' Boston Scott': 31.35,
#   ' Kene Nwangwu': 30.9,
#   ' Deon Jackson': 30.65,
#   ' Raheem Blackshear': 27.2,
#   ' Malik Davis': 27.2,
#   ' James Robinson': 26.55,
#   ' Kevin Harris': 26.3,
#   ' Darrell Henderson': 24.9,
#   ' Trey Sermon': 22.35,
#   " D'Ernest Johnson": 21.15,
#   ' Zonovan Knight': 20.8,
#   ' Keaton Mitchell': 19.25,
#   ' Chris Rodriguez': 18.75,
#   ' Ty Montgomery': 18.45,
#   ' Ronald Jones': 17.5,
#   ' Tyrion Davis-Price': 16.5,
#   ' Hassan Haskins': 15.55,
#   " Ty'Son Williams": 13.85,
#   ' Mark Ingram': 0.0,
#   ' Nyheim Hines': 0.0,
#   ' Darrel Williams': 0.0,
#   ' Eno Benjamin': 0.0,
#   ' Kyle Juszczyk': 0.0,
#   ' Marlon Mack': 0.0,
#   ' Mohamed Ibrahim': 0.0,
#   ' Myles Gaskin': 0.0,
#   ' Alec Ingold': 0.0,
#   ' Adam Prentice': 0.0,
#   ' Keith Smith': 0.0},
#  'QB': {' Josh Allen': 415.7,
#   ' Patrick Mahomes': 374.4,
#   ' Jalen Hurts': 360.8,
#   ' Lamar Jackson': 356.5,
#   ' Justin Herbert': 342.5,
#   ' Joe Burrow': 341.5,
#   ' Trevor Lawrence': 318.9,
#   ' Deshaun Watson': 318.0,
#   ' Justin Fields': 311.2,
#   ' Kirk Cousins': 307.1,
#   ' Anthony Richardson': 298.3,
#   ' Geno Smith': 297.1,
#   ' Tua Tagovailoa': 289.4,
#   ' Dak Prescott': 288.9,
#   ' Daniel Jones': 287.0,
#   ' Jared Goff': 275.4,
#   ' Russell Wilson': 267.2,
#   ' Aaron Rodgers': 263.8,
#   ' Kenny Pickett': 262.5,
#   ' Derek Carr': 251.4,
#   ' Jordan Love': 251.1,
#   ' Bryce Young': 248.3,
#   ' Mac Jones': 247.0,
#   ' Matthew Stafford': 246.9,
#   ' C.J. Stroud': 236.5,
#   ' Sam Howell': 232.1,
#   ' Ryan Tannehill': 232.0,
#   ' Kyler Murray': 218.4,
#   ' Jimmy Garoppolo': 213.5,
#   ' Brock Purdy': 205.5,
#   ' Baker Mayfield': 198.9,
#   ' Desmond Ridder': 197.4,
#   ' Kyle Trask': 53.5,
#   ' Jacoby Brissett': 48.8,
#   ' Trey Lance': 39.1,
#   ' Colt McCoy': 38.1,
#   ' Taylor Heinicke': 37.4,
#   ' Marcus Mariota': 34.5,
#   ' Mike White': 34.4,
#   ' Tyler Huntley': 33.2,
#   ' Sam Darnold': 30.8,
#   ' Jarrett Stidham': 30.8,
#   ' Will Levis': 29.1,
#   ' Tyrod Taylor': 29.0,
#   ' Zach Wilson': 28.7,
#   ' Stetson Bennett': 26.9,
#   ' Gardner Minshew': 16.4,
#   ' Bailey Zappe': 14.3,
#   ' Carson Wentz': 14.2,
#   ' Davis Mills': 12.4,
#   ' Malik Willis': 9.2,
#   ' Jameis Winston': 0.0,
#   ' Nick Mullens': 0.0,
#   ' Kyle Allen': 0.0,
#   ' Matt Ryan': 0.0,
#   ' Case Keenum': 0.0,
#   ' Dorian Thompson-Robinson': 0.0,
#   ' Jake Haener': 0.0,
#   ' Tanner McKee': 0.0,
#   ' Malik Cunningham': 0.0,
#   ' Chase Garbers': 0.0},
#  'TE': {' Travis Kelce': 226.7,
#   ' Mark Andrews': 200.2,
#   ' T.J. Hockenson': 159.8,
#   ' Darren Waller': 155.5,
#   ' Kyle Pitts': 146.55,
#   ' Dallas Goedert': 141.8,
#   ' David Njoku': 135.65,
#   ' George Kittle': 133.35,
#   ' Evan Engram': 133.3,
#   ' Pat Freiermuth': 132.25,
#   ' Chigoziem Okonkwo': 113.9,
#   ' Tyler Higbee': 113.1,
#   ' Dalton Kincaid': 112.0,
#   ' Greg Dulcich': 108.6,
#   ' Dalton Schultz': 107.15,
#   ' Luke Musgrave': 100.3,
#   ' Juwan Johnson': 100.0,
#   ' Sam LaPorta': 100.0,
#   ' Gerald Everett': 94.9,
#   ' Hunter Henry': 94.6,
#   ' Hayden Hurst': 94.05,
#   ' Cole Kmet': 93.75,
#   ' Irv Smith': 92.75,
#   ' Noah Fant': 90.45,
#   ' Mike Gesicki': 89.8,
#   ' Cade Otton': 88.9,
#   ' Tyler Conklin': 88.45,
#   ' Jelani Woods': 87.7,
#   ' Michael Mayer': 87.15,
#   ' Dawson Knox': 86.4,
#   ' Logan Thomas': 79.4,
#   ' Trey McBride': 76.0,
#   ' Taysom Hill': 71.1,
#   ' Jake Ferguson': 66.65,
#   ' Zach Ertz': 64.95,
#   ' Will Dissly': 51.9,
#   ' Adam Trautman': 50.9,
#   ' Austin Hooper': 50.45,
#   ' Foster Moreau': 49.85,
#   ' Luke Schoonmaker': 48.6,
#   ' Isaiah Likely': 48.15,
#   ' Donald Parham': 47.45,
#   ' Noah Gray': 46.4,
#   ' Darnell Washington': 45.7,
#   ' Durham Smythe': 43.0,
#   ' Mo Alie-Cox': 40.5,
#   ' Tucker Kraft': 40.25,
#   ' Cole Turner': 39.5,
#   ' Josh Oliver': 35.9,
#   ' Josh Whyle': 34.7,
#   ' C.J. Uzomah': 33.95,
#   ' Josiah Deguara': 33.0,
#   ' Brenton Strange': 31.4,
#   ' Albert Okwuegbunam': 29.95,
#   ' Colby Parkinson': 26.2,
#   ' Robert Tonyan': 26.05,
#   ' Daniel Bellinger': 25.3,
#   ' Jimmy Graham': 17.25,
#   ' Brock Wright': 17.2,
#   ' Jody Fortson': 0.0,
#   ' Elijah Higgins': 0.0,
#   ' O.J. Howard': 0.0,
#   ' Zack Kuntz': 0.0,
#   ' Pharaoh Brown': 0.0,
#   ' Jace Sternberger': 0.0,
#   ' Jared Pinkney': 0.0,
#   ' Nick Muse': 0.0}}

# %%
## set constraints 

pos_min_wrflex = {
    "QB": 1,
    "RB": 2,
    "WR": 3,
    "TE": 1

}

pos_min_rbflex = {
    "QB": 1,
    "RB": 3,
    "WR": 2,
    "TE": 1

}

auction_dollars = 194.00

# %%
## idk what this is doing (I think creating variables for each k/v pair? so WR_Justin_Jefferson becomes a variable to
## get a 1 or 0 binary?)
_vars = {k: pulp.LpVariable.dict(k, v, cat="Binary") for k, v in points.items()}

# %%
## Let's solve!

## name our problem MaxFF and state we want to maximize something (points)
prob = pulp.LpProblem("Fantasy", pulp.LpMaximize)

#set the empty lists
max_points = []
costs = []
position_constraints = []


for k, v in _vars.items():
    ## sum of player costs
    costs += pulp.lpSum([values[k][i] * _vars[k][i] for i in v])
    ## sum of points
    max_points += pulp.lpSum([points[k][i] * _vars[k][i] for i in v])
    ## constraints on players
    prob += pulp.lpSum([_vars[k][i] for i in v]) <= pos_min_rbflex[k]
    ##prob += pulp.lpSum([pos_flex[k] * _vars[k][i] for i in v]) <= pos_flex_available

## maximize points and keep costs below auction dollars
prob += pulp.lpSum(max_points)
prob += pulp.lpSum(costs) <= auction_dollars

# %%
prob.solve()
# Out:
# 1

# %%
def summary(prob):
    div = '---------------------------------------\n'
    print("Variables:\n")
    score = str(prob.objective)
    constraints = [str(const) for const in prob.constraints.values()]
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraints = [const.replace(v.name, str(v.varValue)) for const in constraints]
        if v.varValue != 0:
            print(v.name, "=", v.varValue)
    print(div)
    print("Constraints:")
    for constraint in constraints:
        constraint_pretty = " + ".join(re.findall("[0-9\.]*\*1.0", constraint))
        if constraint_pretty != "":
            print("{} = {}".format(constraint_pretty, eval(constraint_pretty)))
    print(div)
    print("Score:")
    score_pretty = " + ".join(re.findall("[0-9\.]+\*1.0", score))
    print("{} = {}".format(score_pretty, eval(score)))

# %%
## Set up for objective function 
## convert to dictionaries (consensus) 

##create empty dictionaries
values_c = {}
points_c = {}
##iterate through unique positions
for pos in df_final.position.unique():
    ## create temp df of each position
    available_pos_c = df_final[df_final.position == pos]
    ## create k/v pairs for player and auction value
    value_c = list(available_pos_c[["name","auction_value"]].set_index("name").to_dict().values())[0]
    point_c = list(available_pos_c[["name","consensus_points"]].set_index("name").to_dict().values())[0]
    ## insert into dicts
    values_c[pos] = value_c
    points_c[pos] = point_c
    
## idk what this is doing (I think creating variables for each k/v pair? so WR_Justin_Jefferson becomes a variable to
## get a 1 or 0 binary?)
_vars_c = {k: pulp.LpVariable.dict(k, v, cat="Binary") for k, v in points_c.items()}

# %%
## Let's solve!

## name our problem MaxFF and state we want to maximize something (points)
prob_c = pulp.LpProblem("Fantasy", pulp.LpMaximize)

#set the empty lists
max_points_c = []
costs_c = []
position_constraints_c = []


for k, v in _vars_c.items():
    ## sum of player costs
    costs_c += pulp.lpSum([values_c[k][i] * _vars_c[k][i] for i in v])
    ## sum of points
    max_points_c += pulp.lpSum([points_c[k][i] * _vars_c[k][i] for i in v])
    ## constraints on players
    prob_c += pulp.lpSum([_vars_c[k][i] for i in v]) <= pos_min_rbflex[k]

## maximize points and keep costs below auction dollars
prob_c += pulp.lpSum(max_points_c)
prob_c += pulp.lpSum(costs_c) <= auction_dollars

# %%
prob_c.solve()
# Out:
# 1

# %%
summary(prob_c)
# Out:
# Variables:
#
# QB__Jalen_Hurts = 1.0
# RB__Austin_Ekeler = 1.0
# RB__D'Andre_Swift = 1.0
# RB__Jonathan_Taylor = 1.0
# TE__Travis_Kelce = 1.0
# WR__Christian_Kirk = 1.0
# WR__Jahan_Dotson = 1.0
# ---------------------------------------
#
# Constraints:
# 28.0*1.0 + 63.94240837696335*1.0 + 1.8062827225130889*1.0 + 53.10471204188482*1.0 + 44.95412844036697*1.0 = 191.80753158172826
# ---------------------------------------
#
# Score:
# 385*1.0 + 221*1.0 + 135*1.0 + 206*1.0 + 168*1.0 + 125*1.0 + 125*1.0 = 1365.0

# %%
summary(prob)
# Out:
# Variables:
#
# QB__Josh_Allen = 1.0
# RB__A.J._Dillon = 1.0
# RB__D'Andre_Swift = 1.0
# RB__Khalil_Herbert = 1.0
# TE__Travis_Kelce = 1.0
# WR__A.J._Brown = 1.0
# WR__Justin_Jefferson = 1.0
# ---------------------------------------
#
# Constraints:
# 41.56480938416423*1.0 + 5.493311288140702*1.0 + 1.5868029460393913*1.0 + 4.283330828197819*1.0 + 36.25361512791991*1.0 + 35.749970106421145*1.0 + 69.0*1.0 = 193.93183968088317
# ---------------------------------------
#
# Score:
# 415.7*1.0 + 152.9*1.0 + 147.25*1.0 + 151.15*1.0 + 226.7*1.0 + 223.75*1.0 + 284.2*1.0 = 1601.65

# %%
excel_path = '/Users/cameronfryzel/Documents/FantasyFootball/FF_AuctionDraft_2023.xlsx'

# %%
## Export dataframe to excel sheet across multiple sheets
## df_final.loc[df_final['position'] == 'WR']

with pd.ExcelWriter(excel_path) as writer:
    df_final.loc[df_final['position'] == 'QB'].to_excel(writer, sheet_name = 'QB', index = False)
    df_final.loc[df_final['position'] == 'RB'].to_excel(writer, sheet_name = 'RB', index = False)
    df_final.loc[df_final['position'] == 'WR'].to_excel(writer, sheet_name = 'WR', index = False)
    df_final.loc[df_final['position'] == 'TE'].to_excel(writer, sheet_name = 'TE', index = False)
